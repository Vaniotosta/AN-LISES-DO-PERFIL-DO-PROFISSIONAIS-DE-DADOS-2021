# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaniotosta/ANALISES-DO-PERFIL-DO-PROFISSIONAIS-DE-DADOS-2021/blob/main/Vanio_O_perfil_do_profissional_de_dados_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **- O Perfil do Profissional de Dados no Brasil**

# %% [markdown]
# Atualmente  a área de dados vêm se destacando em muitos aspectos, e cada vez mais os profissionais de dados são requisitados por muitas empresas, é importante saber o perfil desses profissionais de dados.
#
#
# Sendo assim, o pessoal do Data Hackers realizou uma grande pesquisa em nível nacional para traçar o perfil desses profissionais. Foram entrevistados 2645 pessoas que responderam sobre diversas variáveis de suas carreirais, desde salário e tempo de experiência até plataformas de ensino e conceitos mais utilizados.
#
#
#
# **O objetivo dessa análise é entender  o perfil do profissional da área de dados no Brasil.**
#
# É importante relatar que apesar da pesquisa ser realizada a todo profissioniais de dados, essa análise gera insights dando destaques aos profissionais de **análise de dados e cientista de dados**
#
#
#  Ao entender os dados, e considerando algumas considerações, foi criado algumas variáveis novas para auxiliar na análise. Em seguida, respondemos sequencialmente diversas perguntas levantadas com o intuito de traçar o perfil desejado.

# %% [markdown]
# ## **Possíveis Perguntas**
#
# 1. Pergunta: Qual o perfil geral do profissional da área de dados no Brasil?
# 1. Pergunta: Qual o perfil dos que se consideram atuar em Data Science?
# 3. Pergunta: Qual o perfil do profissional empregado como Cientista de Dados?
# 3. Pergunta: Vale a pena fazer pós-graduação?
# 3. Pergunta: Há desigualdade nos salários em relação ao gênero na área de dados no Brasil?
# 3. Pergunta: Quais são as habilidades mais predominantes nos Cientistas de Dados?
# 3. Pergunta: Quais são os salários em relação às linguagens mais utilizadas?
# 3. Pergunta: Quais são os salários em relação ao tipo de emprego?
# 3. Pergunta: Quais são os salários em relação as plataformas de ensino preferidas?
# 3. Pergunta: Quais são os salários em relação tempo de experiência?
# 3. Pergunta: Como os cargos se distribuem em relação ao tempo de experiência?
# 3. Pergunta: Como os profissionais estão distribuídos em seus empregos em relação às suas formações?

# %%
# importação de dados via github

#link = "https://raw.githubusercontent.com/ricardorocha86/Datasets/master/PesquisaDH/State%20of%20Data%202021%20-%20Dataset%20-%20Pgina1.csv"
#import pandas as pd

#dados = pd.read_csv(link)

#dados.sample(7)

# %% [markdown]
# Aqui foi feito a importação dos dados para que se conheça o dataset, ter uma visão geral se existem ruídos nos dados como dados ausentes, conhecendo as variáveis e as informações preliminares, é de fundamental importância conhecer os requisitos do dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# aqui importei diretamente dataset para minha máquna
import pandas as pd
dados = pd.read_csv('/content/drive/MyDrive/dadosperfil_datahacker/State of Data 2021 - Dataset - Pgina1.csv')



dados.sample(7)
# Out:
# <ipython-input-3-b17b9b2699b4>:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('/content/drive/MyDrive/dadosperfil_datahacker/State of Data 2021 - Dataset - Pgina1.csv')
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 1421  jyctpl5apbklpt2jyctpmyhjyu1kockc                32.0
# 1406  k6vr4wt0o7efjtynimsk6vr4i5qknhmc                22.0
# 2061  9gefd0fvmubyfzylr9ge7nd4mou2h7fr                29.0
# 524   z838y1xhjhxcz5lbuimr3z838y11iu56                32.0
# 2291  5ry7z9nehxbcrthe3v5ry7dqnsy13zsv                28.0
# 2097  8t00061syagak1vzzxb8t000mz94hvgz                33.0
# 1581  pekk0qtha631ukzvvt8pekk00r4tm9dt                36.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 1421                      30-34            Feminino
# 1406                      22-24           Masculino
# 2061                      25-29           Masculino
# ...

# %% [markdown]
# ## Colunas
#
# 1.	["('P0', 'id')",
# 2.	"('P1_a ', 'Idade')",
# 3.	"('P1_a_a ', 'Faixa idade')",
# 4.	"('P1_b ', 'Genero')",
# 5.	"('P1_e ', 'Estado onde mora')",
# 6.	"('P1_e_a ', 'uf onde mora')",
# 7.	"('P1_e_b ', 'Regiao onde mora')",
# 8.	"('P1_g_b ', 'Regiao de origem')",
# 9.	"('P1_g_c ', 'Mudou de Estado?')",
# 10.	"('P1_h ', 'Nivel de Ensino')",
# 11.	"('P1_i ', 'Área de Formação')",
# 12.	"('P2_a ', 'Qual sua situação atual de trabalho?')",
# 13.	"('P2_b ', 'Setor')",
# 14.	"('P2_c ', 'Numero de Funcionarios')",
# 15.	"('P2_d ', 'Gestor?')",
# 16.	"('P2_e ', 'Cargo como Gestor')",
# 17.	"('P2_f ', 'Cargo Atual')",
# 18.	"('P2_g ', 'Nivel')",
# 19.	"('P2_h ', 'Faixa salarial')",
# 20.	"('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
# 21.	"('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
# 22.	"('P2_k ', 'Você está satisfeito na sua empresa atual?')",
# 23.	"('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
# 24.	"('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')",
# 25.	"('P2_l_b ', 'Salário atual não corresponde ao mercado')",
# 26.	"('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')",
# 27.	"('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')",
# 28.	"('P2_l_e ', 'Gostaria de receber mais benefícios')",
# 29.	"('P2_l_f ', 'O clima de trabalho/ambiente não é bom')",
# 30.	"('P2_l_g ', 'Falta de maturidade analítica na empresa')",
# 31.	"('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
# 32.	"('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')",
# 33.	"('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
# 34.	"('P2_o_a ', 'Remuneração/Salário')",
# 35.	"('P2_o_b ', 'Benefícios')",
# 36.	"('P2_o_c ', 'Propósito do trabalho e da empresa')",
# 37.	"('P2_o_d ', 'Flexibilidade de trabalho remoto')",
# 38.	"('P2_o_e ', 'Ambiente e clima de trabalho')",
# 39.	"('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
# 40.	"('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')",
# 41.	"('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')",
# 42.	"('P2_o_i ', 'Qualidade dos gestores e líderes')",
# 43.	"('P2_o_j ', 'Reputação que a empresa tem no mercado')",
# 44.	"('P2_q ', 'Atualmente qual a sua forma de trabalho?')",
# 45.	"('P2_r ', 'Qual a forma de trabalho ideal para você?')",
# 46.	"('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')",
# 47.	"('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')",
# 48.	"('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')",
# 49.	"('P3_b_a ', 'Analytics Engineer')",
# 50.	"('P3_b_b ', 'Engenharia de Dados/Data Engineer')",
# 51.	"('P3_b_c ', 'Analista de Dados/Data Analyst')",
# 52.	"('P3_b_d ', 'Cientista de Dados/Data Scientist')",
# 53.	"('P3_b_e ', 'Database Administrator/DBA')",
# 54.	"('P3_b_f ', 'Analista de Business Intelligence/BI')",
# 55.	"('P3_b_g ', 'Arquiteto de Dados/Data Architect')",
# 56.	"('P3_b_h ', 'Data Product Manager/DPM')",
# 57.	"('P3_b_i ', 'Business Analyst')",
# 58.	"('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')",
# 59.	"('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')",
# 60.	"('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')",
# 61.	"('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')",
# 62.	"('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')",
# 63.	"('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')",
# 64.	"('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')",
# 65.	"('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')",
# 66.	"('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')",
# 67.	"('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')",
# 68.	"('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')",
# 69.	"('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')",
# 70.	"('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')",
# 71.	"('P3_d_ ', 'a Contratar novos talentos.')",
# 72.	"('P3_d_ ', 'b Reter talentos.')",
# 73.	"('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')",
# 74.	"('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')",
# 75.	"('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')",
# 76.	"('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')",
# 77.	"('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')",
# 78.	"('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')",
# 79.	"('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')",
# 80.	"('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')",
# 81.	"('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')",
# 82.	"('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')",
# 83.	"('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')",
# 84.	"('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')",
# 85.	"('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')",
# 86.	"('P4_a ', 'Atuacao')",
# 87.	"('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')",
# 88.	"('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')",
# 89.	"('P4_b_b ', 'Dados armazenados em bancos NoSQL')",
# 90.	"('P4_b_c ', 'Imagens')",
# 91.	"('P4_b_d ', 'Textos/Documentos')",
# 92.	"('P4_b_e ', 'Vídeos')",
# 93.	"('P4_b_f ', 'Áudios')",
# 94.	"('P4_b_g ', 'Planilhas')",
# 95.	"('P4_b_h ', 'Dados georeferenciados')",
# 96.	"('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')",
# 97.	"('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')",
# 98.	"('P4_c_b ', 'Dados armazenados em bancos NoSQL')",
# 99.	"('P4_c_c ', 'Imagens')",
# 100.	"('P4_c_d ', 'Textos/Documentos')",
# 101.	"('P4_c_e ', 'Vídeos')",
# 102.	"('P4_c_f ', 'Áudios')",
# 103.	"('P4_c_g ', 'Planilhas')",
# 104.	"('P4_c_h ', 'Dados georeferenciados')",
# 105.	"('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')",
# 106.	"('P4_d_a ', 'SQL')",
# 107.	"('P4_d_b ', 'R ')",
# 108.	"('P4_d_c ', 'Python')",
# 109.	"('P4_d_d ', 'C/C++/C#')",
# 110.	"('P4_d_e ', '.NET')",
# 111.	"('P4_d_f ', 'Java')",
# 112.	"('P4_d_g ', 'Julia')",
# 113.	"('P4_d_h ', 'SAS/Stata')",
# 114.	"('P4_d_i ', 'Visual Basic/VBA')",
# 115.	"('P4_d_j ', 'Scala')",
# 116.	"('P4_d_k ', 'Matlab')",
# 117.	"('P4_d_l ', 'PHP')",
# 118.	"('P4_d_m ', 'Javascript')",
# 119.	"('P4_d_n ', 'Não utilizo nenhuma linguagem')",
# 120.	"('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')",
# 121.	"('P4_e_a ', 'SQL')",
# 122.	"('P4_e_b ', 'R ')",
# 123.	"('P4_e_c ', 'Python')",
# 124.	"('P4_e_d ', 'C/C++/C#')",
# 125.	"('P4_e_e ', '.NET')",
# 126.	"('P4_e_f ', 'Java')",
# 127.	"('P4_e_g ', 'Julia')",
# 128.	"('P4_e_h ', 'SAS/Stata')",
# 129.	"('P4_e_i ', 'Visual Basic/VBA')",
# 130.	"('P4_e_j ', 'Scala')",
# 131.	"('P4_e_k ', 'Matlab')",
# 132.	"('P4_e_l ', 'PHP')",
# 133.	"('P4_e_m ', 'Javascript')",
# 134.	"('P4_e_n ', 'Não utilizo nenhuma linguagem')",
# 135.	"('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')",
# 136.	"('P4_f_a ', 'MySQL')",
# 137.	"('P4_f_b ', 'Oracle')",
# 138.	"('P4_f_c ', 'SQL SERVER')",
# 139.	"('P4_f_d ', 'SAP')",
# 140.	"('P4_f_e ', 'Amazon Aurora ou RDS')",
# 141.	"('P4_f_f ', 'Amazon DynamoDB')",
# 142.	"('P4_f_g ', 'CoachDB')",
# 143.	"('P4_f_h ', 'Cassandra')",
# 144.	"('P4_f_i ', 'MongoDB')",
# 145.	"('P4_f_j ', 'MariaDB')",
# 146.	"('P4_f_k ', 'Datomic')",
# 147.	"('P4_f_l ', 'S3')",
# 148.	"('P4_f_m ', 'PostgreSQL')",
# 149.	"('P4_f_n ', 'ElasticSearch')",
# 150.	"('P4_f_o ', 'DB2')",
# 151.	"('P4_f_p ', 'Microsoft Access')",
# 152.	"('P4_f_q ', 'SQLite')",
# 153.	"('P4_f_r ', 'Sybase')",
# 154.	"('P4_f_s ', 'Firebase')",
# 155.	"('P4_f_t ', 'Vertica')",
# 156.	"('P4_f_u ', 'Redis')",
# 157.	"('P4_f_v ', 'Neo4J')",
# 158.	"('P4_f_x ', 'Google BigQuery')",
# 159.	"('P4_f_y ', 'Google Firestore')",
# 160.	"('P4_f_z ', 'Amazon Redshift')",
# 161.	"('P4_f_z1 ', 'Amazon Athena')",
# 162.	"('P4_f_z2 ', 'Snowflake')",
# 163.	"('P4_f_z3 ', 'Databricks')",
# 164.	"('P4_f_z4 ', 'HBase')",
# 165.	"('P4_f_z5 ', 'Presto')",
# 166.	"('P4_f_z6 ', 'Splunk')",
# 167.	"('P4_f_z7 ', 'SAP HANA')",
# 168.	"('P4_f_z8 ', 'Hive')",
# 169.	"('P4_f_z9 ', 'Firebird')",
# 170.	"('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')",
# 171.	"('P4_g_a ', 'Amazon Web Services (AWS)')",
# 172.	"('P4_g_b ', 'Google Cloud (GCP)')",
# 173.	"('P4_g_c ', 'Azure (Microsoft)')",
# 174.	"('P4_g_d ', 'Oracle Cloud')",
# 175.	"('P4_g_e ', 'IBM')",
# 176.	"('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')",
# 177.	"('P4_g_g ', 'Cloud Própria')",
# 178.	"('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')",
# 179.	"('P4_h_a ', 'Microsoft PowerBI')",
# 180.	"('P4_h_b ', 'Qlik View/Qlik Sense')",
# 181.	"('P4_h_c ', 'Tableau')",
# 182.	"('P4_h_d ', 'Metabase')",
# 183.	"('P4_h_e ', 'Superset')",
# 184.	"('P4_h_f ', 'Redash')",
# 185.	"('P4_h_g ', 'MicroStrategy')",
# 186.	"('P4_h_h ', 'IBM Analytics/Cognos')",
# 187.	"('P4_h_i ', 'SAP Business Objects')",
# 188.	"('P4_h_j ', 'Oracle Business Intelligence')",
# 189.	"('P4_h_k ', 'Amazon QuickSight')",
# 190.	"('P4_h_l ', 'Salesforce/Einstein Analytics')",
# 191.	"('P4_h_m ', 'Mode')",
# 192.	"('P4_h_n ', 'Alteryx')",
# 193.	"('P4_h_o ', 'Birst')",
# 194.	"('P4_h_p ', 'Looker')",
# 195.	"('P4_h_q ', 'Google Data Studio')",
# 196.	"('P4_h_r ', 'SAS Visual Analytics')",
# 197.	"('P4_h_s ', 'Grafana')",
# 198.	"('P4_h_t ', 'TIBCO Spotfire')",
# 199.	"('P4_h_u ', 'Pentaho')",
# 200.	"('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')",
# 201.	"('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')",
# 202.	"('P5_b ', 'Qual oportunidade você está buscando?')",
# 203.	"('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
# 204.	"('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
# 205.	"('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')",
# 206.	"('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
# 207.	"('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
# 208.	"('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
# 209.	"('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
# 210.	"('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
# 211.	"('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
# 212.	"('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
# 213.	"('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')",
# 214.	"('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
# 215.	"('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')",
# 216.	"('P6_b_a ', 'Scripts Python')",
# 217.	"('P6_b_b ', 'SQL & Stored Procedures')",
# 218.	"('P6_b_c ', 'Apache Airflow')",
# 219.	"('P6_b_d ', 'Luigi')",
# 220.	"('P6_b_e ', 'AWS Glue')",
# 221.	"('P6_b_f ', 'Talend')",
# 222.	"('P6_b_g ', 'Stitch')",
# 223.	"('P6_b_h ', 'Fivetran')",
# 224.	"('P6_b_i ', 'Google Dataflow')",
# 225.	"('P6_b_j ', 'Oracle Data Integrator')",
# 226.	"('P6_b_k ', 'IBM DataStage')",
# 227.	"('P6_b_l ', 'SAP BW ETL')",
# 228.	"('P6_b_m ', 'SQL Server Integration Services (SSIS)')",
# 229.	"('P6_b_n ', 'SAS Data Integration')",
# 230.	"('P6_b_o ', 'Qlik Sense')",
# 231.	"('P6_b_p ', 'Knime')",
# 232.	"('P6_b_q ', 'Não utilizo ferramentas de ETL')",
# 233.	"('P6_c ', 'Sua organização possui um Data Lake?')",
# 234.	"('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')",
# 235.	"('P6_e ', 'Sua organização possui um Data Warehouse?')",
# 236.	"('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')",
# 237.	"('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')",
# 238.	"('P6_g_a ', 'great_expectations')",
# 239.	"('P6_g_b ', 'dbt')",
# 240.	"('P6_g_c ', 'AWS Deequ')",
# 241.	"('P6_g_d ', 'Apache Griffin')",
# 242.	"('P6_g_e ', 'Datafold')",
# 243.	"('P6_g_f ', 'Amundsen')",
# 244.	"('P6_g_g ', 'Monte Carlo')",
# 245.	"('P6_g_h ', 'SODA')",
# 246.	"('P6_g_i ', 'Big Eye')",
# 247.	"('P6_g_j ', 'Data Band')",
# 248.	"('P6_g_k ', 'Anomalo')",
# 249.	"('P6_g_l ', 'Metaplane')",
# 250.	"('P6_g_m ', 'Acceldata')",
# 251.	"('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')",
# 252.	"('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
# 253.	"('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
# 254.	"('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
# 255.	"('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
# 256.	"('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
# 257.	"('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
# 258.	"('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
# 259.	"('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')",
# 260.	"('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')",
# 261.	"('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')",
# 262.	"('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
# 263.	"('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')",
# 264.	"('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
# 265.	"('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
# 266.	"('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
# 267.	"('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')",
# 268.	"('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')",
# 269.	"('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')",
# 270.	"('P7_b_a ', 'Scripts Python')",
# 271.	"('P7_b_b ', 'SQL & Stored Procedures')",
# 272.	"('P7_b_c ', 'Apache Airflow')",
# 273.	"('P7_b_d ', 'Luigi')",
# 274.	"('P7_b_e ', 'AWS Glue')",
# 275.	"('P7_b_f ', 'Talend')",
# 276.	"('P7_b_g ', 'Stitch')",
# 277.	"('P7_b_h ', 'Fivetran')",
# 278.	"('P7_b_i ', 'Google Dataflow')",
# 279.	"('P7_b_j ', 'Oracle Data Integrator')",
# 280.	"('P7_b_k ', 'IBM DataStage')",
# 281.	"('P7_b_l ', 'SAP BW ETL')",
# 282.	"('P7_b_m ', 'SQL Server Integration Services (SSIS)')",
# 283.	"('P7_b_n ', 'SAS Data Integration')",
# 284.	"('P7_b_o ', 'Qlik Sense')",
# 285.	"('P7_b_p ', 'Knime')",
# 286.	"('P7_b_q ', 'Não utilizo ferramentas de ETL')",
# 287.	"('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')",
# 288.	"('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')",
# 289.	'(\'P7_c_b \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')',
# 290.	"('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')",
# 291.	"('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')",
# 292.	"('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')",
# 293.	"('P7_c_f ', 'Não sei informar.')",
# 294.	"('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')",
# 295.	"('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')",
# 296.	"('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
# 297.	"('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')",
# 298.	"('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
# 299.	"('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
# 300.	"('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
# 301.	"('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')",
# 302.	"('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
# 303.	"('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')",
# 304.	"('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
# 305.	"('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')",
# 306.	"('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
# 307.	"('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
# 308.	"('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')",
# 309.	"('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
# 310.	"('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')",
# 311.	"('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
# 312.	"('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
# 313.	"('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')",
# 314.	"('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')",
# 315.	"('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')",
# 316.	"('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')",
# 317.	"('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')",
# 318.	"('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')",
# 319.	"('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')",
# 320.	"('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')",
# 321.	"('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')",
# 322.	"('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')",
# 323.	"('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')",
# 324.	"('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')",
# 325.	"('P8_b_l ', 'Utilizo métodos de Visão Computacional')",
# 326.	"('P8_b_m ', 'Utilizo modelos de Detecção de Churn')",
# 327.	"('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')",
# 328.	"('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')",
# 329.	"('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')",
# 330.	"('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')",
# 331.	"('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')",
# 332.	"('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')",
# 333.	"('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')",
# 334.	"('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')",
# 335.	"('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')",
# 336.	"('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')",
# 337.	"('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')",
# 338.	"('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')",
# 339.	"('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')",
# 340.	"('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')",
# 341.	"('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')",
# 342.	"('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
# 343.	"('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
# 344.	"('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')",
# 345.	"('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
# 346.	"('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')",
# 347.	"('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')",
# 348.	"('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')",
# 349.	"('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
# 350.	"('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')",
# 351.	"('P9_a_a ', 'Blog/Medium do Data Hackers')",
# 352.	"('P9_a_b ', 'Podcast do Data Hackers')",
# 353.	"('P9_a_d ', 'Newsletter Semanal')",
# 354.	"('P9_a_e ', 'Canal do Slack')",
# 355.	"('P9_a_f ', 'Canal do Youtube do Data Hackers')",
# 356.	"('P9_a_g ', 'Ainda não conhecia o Data Hackers')"]

# %% [markdown]
# A verificação do shape nos dá a dimensão das quantidades de linhas e colunas do dataset, isso é importante dentre várias formas , principalmente em definir uma amostra dos dados, principalmente com objetivo de poupar memória

# %%
# verifiquei quantidade de colunas e linhas
dados.shape
# Out:
# (2645, 356)

# %% [markdown]
# Aqui foi feito a exploração  das principais informações do dataset,onde temos 293 número float(decimais), 7 valores inteiros e 56 tipo objetos(texto), o que requer atenção se fosse fazer uma modelagem.

# %%
# buscando as informações 
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Columns: 356 entries, ('P0', 'id') to ('P9_a_g ', 'Ainda não conhecia o Data Hackers')
# dtypes: float64(293), int64(7), object(56)
# memory usage: 7.2+ MB

# %% [markdown]
# Aqui foi feito a buscas das colunas e seu valores, ou seja, respostas realizadas

# %%
# aqui busco as colunas com seus valores
dados.columns.values
# Out:
# array(["('P0', 'id')", "('P1_a ', 'Idade')", "('P1_a_a ', 'Faixa idade')",
#        "('P1_b ', 'Genero')", "('P1_e ', 'Estado onde mora')",
#        "('P1_e_a ', 'uf onde mora')", "('P1_e_b ', 'Regiao onde mora')",
#        "('P1_g_b ', 'Regiao de origem')",
#        "('P1_g_c ', 'Mudou de Estado?')", "('P1_h ', 'Nivel de Ensino')",
#        "('P1_i ', 'Área de Formação')",
#        "('P2_a ', 'Qual sua situação atual de trabalho?')",
#        "('P2_b ', 'Setor')", "('P2_c ', 'Numero de Funcionarios')",
#        "('P2_d ', 'Gestor?')", "('P2_e ', 'Cargo como Gestor')",
#        "('P2_f ', 'Cargo Atual')", "('P2_g ', 'Nivel')",
#        "('P2_h ', 'Faixa salarial')",
#        "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#        "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#        "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
# ...

# %% [markdown]
# ## Verificando por dados faltantes

# %%
# buscando a média dos dados nulos incluindo os zerados
dados.isnull().mean( ).sort_values(ascending=False)
# Out:
# ('P5_b ', 'Qual oportunidade você está buscando?')                            0.940643
# ('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')           0.939887
# ('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')    0.939130
# ('P6_g_m ', 'Acceldata')                                                      0.921361
# ('P6_g_g ', 'Monte Carlo')                                                    0.921361
#                                                                                 ...
# ('P1_g_c ', 'Mudou de Estado?')                                               0.000000
# ('P1_e_b ', 'Regiao onde mora')                                               0.000000
# ('P1_b ', 'Genero')                                                           0.000000
# ('P1_a_a ', 'Faixa idade')                                                    0.000000
# ('P9_a_g ', 'Ainda não conhecia o Data Hackers')                              0.000000
# ...

# %%
#Buscando dados nulos por colunas
dados.isnull().sum() != 0
# Out:
# ('P0', 'id')                                        False
# ('P1_a ', 'Idade')                                   True
# ('P1_a_a ', 'Faixa idade')                          False
# ('P1_b ', 'Genero')                                 False
# ('P1_e ', 'Estado onde mora')                        True
#                                                     ...
# ('P9_a_b ', 'Podcast do Data Hackers')              False
# ('P9_a_d ', 'Newsletter Semanal')                   False
# ('P9_a_e ', 'Canal do Slack')                       False
# ('P9_a_f ', 'Canal do Youtube do Data Hackers')     False
# ('P9_a_g ', 'Ainda não conhecia o Data Hackers')    False
# Length: 356, dtype: bool

# %% [markdown]
# Logo abaixo estou buscando a média dos dados nulos diferente dos zerados e ordenando do maior para menor, isso nos mostra que temos muitos dados nulos na pesquisa, ou seja tem variáveis que estão acima de 90% de dados nulos

# %%
# dados faltantes diferentes de zero
dados.isnull().mean()[ dados.isnull().sum() != 0 ].sort_values(ascending = False)
# Out:
# ('P5_b ', 'Qual oportunidade você está buscando?')                            0.940643
# ('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')           0.939887
# ('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')    0.939130
# ('P6_g_c ', 'AWS Deequ')                                                      0.921361
# ('P6_g_k ', 'Anomalo')                                                        0.921361
#                                                                                 ...
# ('P2_q ', 'Atualmente qual a sua forma de trabalho?')                         0.105860
# ('P1_i ', 'Área de Formação')                                                 0.024197
# ('P1_e ', 'Estado onde mora')                                                 0.013611
# ('P1_e_a ', 'uf onde mora')                                                   0.013611
# ('P1_a ', 'Idade')                                                            0.010586
# ...

# %% [markdown]
# ##**Cargo Atual**

# %%
# Busando o percentual de valores nulos por cargo atual
print(dados["('P2_f ', 'Cargo Atual')"].isnull().value_counts(normalize=True));

# Contagem dos valores dos nulos dos cargos
print(dados["('P2_f ', 'Cargo Atual')"].isnull().value_counts().plot(kind = 'barh', title='Contagem dos valores nulos dos cargos', color=['#6cc570','#c5706c'],figsize=(10,5), 
                                                                     ))
# Out:
# False    0.702079
# True     0.297921
# Name: ('P2_f ', 'Cargo Atual'), dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Quanto ao cargo atual percebe-se 29,7% dos dados são ausentes, ou seja, a minoria , o que nos dá um retrato positivo da realidade dos fatos quanto as definições dos cargos.

# %%
# buscando os 4 maiores valores dos cargos
maiores_valores = sorted(dados["('P2_f ', 'Cargo Atual')"].value_counts(), reverse=True)[:4]
# definindo as cores dos gráficos[:3]
cores = ['gray' if valor in maiores_valores else 'blue' for valor in dados["('P2_f ', 'Cargo Atual')"].value_counts(ascending=True) ]

# %%
# Contagem dos cargos

print(dados["('P2_f ', 'Cargo Atual')"].value_counts())
print(dados["('P2_f ', 'Cargo Atual')"].value_counts(ascending=True).plot(kind = 'barh', title='Contagem dos valores por cargos', color=cores,figsize=(20,8),edgecolor = 'black'
                                                                     ))
# Out:
# Cientista de Dados/Data Scientist                          357
# Analista de BI/BI Analyst/Analytics Engineer               338
# Analista de Dados/Data Analyst                             324
# Engenheiro de Dados/Data Engineer                          300
# Outro                                                      113
# Analista de Negócios/Business Analyst                       96
# Desenvolvedor ou Engenheiro de Software                     92
# Engenheiro de Machine Learning/ML Engineer                  48
# Outras Engenharias (não inclui dev)                         33
# Estatístico                                                 25
# Analista Administrativo                                     18
# Analista de Inteligência de Mercado/Market Intelligence     18
# Analista de Marketing                                       14
# DBA/Administrador de Banco de Dados                         14
# Analista de Sistemas/Analista de TI                         14
# ...

# %% [markdown]
# Aqui existem uma predominãncia de variedades de cargos com nomenclaturas semelhantes que requer uma engenharia de variáveis,sendo assim levarei em consideração as variáveis de maiores valores.

# %% [markdown]
# ##**Formação**

# %%
# buscando os 4 maiores valores dos cargos
maiores_valores = sorted(dados["('P1_i ', 'Área de Formação')"].value_counts(), reverse=True)[:4]
# definindo as cores dos gráficos
cores = ['gray' if valor in maiores_valores else 'blue' for valor in dados["('P1_i ', 'Área de Formação')"].value_counts(ascending=True)]

# %%
# contando valores das formações em percentuais
print(dados["('P1_i ', 'Área de Formação')"].value_counts(normalize=True))
# contando valores das formações
print(dados["('P1_i ', 'Área de Formação')"].value_counts(ascending=True).plot(kind = 'barh', title='Contagem dos valores por Área de Formação', color=cores,figsize=(15,6),edgecolor = 'black'
                                                                     ))
# Out:
# Computação / Engenharia de Software / Sistemas de Informação/ TI    0.424642
# Outras Engenharias                                                  0.234793
# Economia/ Administração / Contabilidade / Finanças                  0.146455
# Estatística/ Matemática / Matemática Computacional                  0.082914
# Marketing / Publicidade / Comunicação / Jornalismo                  0.029059
# Química / Física                                                    0.028284
# Outras                                                              0.020147
# Ciências Biológicas/Farmácia/Medicina/Área da Saúde                 0.018210
# Ciências Sociais                                                    0.015498
# Name: ('P1_i ', 'Área de Formação'), dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Aqui percebe-se que a maioria dos profissionais de dados são da área de TI (42,2%), seguido por outras engenharias (23,4%)  e profissionais da área de negócio (16,6%), isso mostra que existem margem de crescimento para todas as áreas no setor, apesar da prevalência dos profissionais de TI

# %% [markdown]
# ##**Engenharia de variáveis /Profissão Atualizada**

# %% [markdown]
# Como foi dito nas análises acima que existem profissões com variedades de nomenclaturas com atividades semelhantes, foi necessário uma categorização dessas profissões para que se tenha um diagnótico mais preciso, sendo assim, foi agrupado as profissões de acordo com as principais áreas.

# %%
# fazendo reagrupamento das profissões
prof_atualizadas = {'Desenvolvedor ou Engenheiro de Software': 'Outras', 
                                             'Outro': 'Outras',
                 'Cientista de Dados/Data Scientist': 'Cientista de Dados',
                    'Analista de Dados/Data Analyst': 'Analista de Dados',
      'Analista de BI/BI Analyst/Analytics Engineer': 'Analista de BI',
                 'Engenheiro de Dados/Data Engineer': 'Engenheiro de Dados',
             'Analista de Negócios/Business Analyst': 'Analista de BI',
'Analista de Inteligência de Mercado/Market Intelligence': 'Analista de BI',
                                        'Engenheiro': 'Outras',
               'Outras Engenharias (não inclui dev)': 'Outras',
                             'Analista de Marketing': 'Outras',
        'Engenheiro de Machine Learning/ML Engineer': 'Engenheiro de ML',
               'DBA/Administrador de Banco de Dados': 'Engenheiro de Dados',
                                       'Estatístico': 'Cientista de Dados',
                                        'Economista': 'Outras',
                                'Arquiteto de Dados': 'Engenheiro de Dados',
                                'Arquiteto de dados': 'Engenheiro de Dados',
                           'Analista Administrativo': 'Outras',
                                   'Product Manager': 'Outras',
              'Analista de Sistemas/Analista de TI' : 'Outras',
                                   'Suporte Técnico': 'Outras',
                                           'Técnico': 'Outras',
                                         'Professor': 'Outras',
           }

           
dados['profissao'] = dados["('P2_f ', 'Cargo Atual')"].map(prof_atualizadas)

# %%
# Contando valores das profissões em percentuais
print(dados['profissao'].value_counts(normalize=True))
#Contando valores das profissões
print(dados['profissao'].value_counts(ascending=True).plot(kind = 'barh', title='Contagem dos valores das profissões', color=cores,figsize=(10,6),edgecolor = 'black'
                                                                     ))
# Out:
# Analista de BI         0.243403
# Cientista de Dados     0.205708
# Outras                 0.176629
# Analista de Dados      0.174475
# Engenheiro de Dados    0.173936
# Engenheiro de ML       0.025848
# Name: profissao, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Aqui verifica- se que os analista de BI são a maioria com (24,3%), seguido por cientista de dados com (20,5%), outras profissões que são atividades ligadas à dados (17,6%) e os analista de dados e engenheiros de dados (17%), isso nos deixa claro as profissões que mais contribuiram  para pesquisa

# %% [markdown]
# ##**Idade**

# %%
# Buscando estatistica da idade
dados["('P1_a ', 'Idade')"].describe()
# Out:
# count    2617.00000
# mean       31.15705
# std         7.13062
# min        18.00000
# 25%        26.00000
# 50%        30.00000
# 75%        35.00000
# max        54.00000
# Name: ('P1_a ', 'Idade'), dtype: float64

# %%
# Verificando a distrbuição das idades
dados["('P1_a ', 'Idade')"].plot(kind = 'hist',
                                 edgecolor = 'black',
                                 title='Distribuição das idades',
                                 color=['#6cc570','#706cc5'],
                                 figsize=(10,6),
                                 );

# %% [markdown]
# Aqui verifica-se que **a média das idade é de 31 anos**, essas idades **variam entre 18 e 54 anos**,e que a metade dos entrevistados estão acima dos 30 anos.Esse dados se validam no gráfico de distribuição das idades, os dados mostram que a área de dados é bastante diversificada, isso requer uma  análise mais detalhada.

# %%
# Buscando a faixa de ditrbuição das idades
dados["('P1_a_a ', 'Faixa idade')"]
# Out:
# 0       35-39
# 1       35-39
# 2       30-34
# 3       35-39
# 4       35-39
#         ...
# 2640    40-44
# 2641    25-29
# 2642    22-24
# 2643    35-39
# 2644    25-29
# Name: ('P1_a_a ', 'Faixa idade'), Length: 2645, dtype: object

# %%
# Plotando a distrbuição das faixas de idade
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(dados["('P1_a_a ', 'Faixa idade')"],bins=10, color= 'red', label='distribuição', alpha=0.3, edgecolor = 'black')
plt.xlabel('Faixa de Idade')
plt.ylabel('frequencia')
plt.title('DISTRIBUIÇÃO DA FAIXA DA IDADES');

# %% [markdown]
# A faixa etária predominante dos pesquisados **se concentram entre 25 e 34 anos**, sendo que a partir dos 50 anos têm poucos pesquisados

# %% [markdown]
# ##**Faixa Salarial**

# %% [markdown]
# Aqui é preciso fazer uma categorização de faixas salarial para que seja mais interpretáveis, faremos uma engenharia de variáveis agrupando empresas por porte e faixas salariais.

# %%
#buscando a faixa salarial
dados["('P2_h ', 'Faixa salarial')"].value_counts()
# Out:
# de R$ 8.001/mês a R$ 12.000/mês     479
# de R$ 4.001/mês a R$ 6.000/mês      403
# de R$ 6.001/mês a R$ 8.000/mês      393
# de R$ 12.001/mês a R$ 16.000/mês    263
# de R$ 3.001/mês a R$ 4.000/mês      183
# de R$ 2.001/mês a R$ 3000/mês       180
# de R$ 16.001/mês a R$ 20.000/mês    129
# de R$ 1.001/mês a R$ 2.000/mês      126
# de R$ 20.001/mês a R$ 25.000/mês     62
# de R$ 25.001/mês a R$ 30.000/mês     43
# de R$ 30.001/mês a R$ 40.000/mês     38
# Acima de R$ 40.001/mês               34
# Menos de R$ 1.000/mês                32
# Name: ('P2_h ', 'Faixa salarial'), dtype: int64

# %%
#Plotando a faixa salarial
dados["('P2_h ', 'Faixa salarial')"].value_counts().plot(kind = 'barh',
                                 edgecolor = 'black',
                                 title='Faixa salarials',
                                 color='b',
                                 figsize=(10,6),
                                 );

# %% [markdown]
# Conforme validado no gráfico acima , é preciso um ajuste nas faixas salariais para melhor interpretação, aqui será usado um pré processamento básico para facilitar a interpretação.

# %% [markdown]
# #**Pré-processamento básico**

# %% [markdown]
# Aqui foi feito alguns pré processamento como; renomear colunas e categorização para que as variáveis sejam mais legivéis e intepretáveis, mas sem preder os seu reais valores.

# %%
# Pré-processamento básico

# criando variáveis mais convenientes

# empresa
tammap = { 'de 1 a 5': 'Pequena',
           'de 6 a 10': 'Pequena',
           'de 11 a 50': 'Pequena',
           'de 51 a 100': 'Pequena',
           'de 101 a 500': 'Média',
           'de 501 a 1000': 'Média',
           'de 1001 a 3000': 'Grande',
           'Acima de 3000': 'Grande'}

dados['tamanho_da_empresa'] = dados["('P2_c ', 'Numero de Funcionarios')"].map(tammap) 
 
# salarios
salamap = {    'Menos de R$ 1.000/mês': 1000,
      'de R$ 1.001/mês a R$ 2.000/mês': 1500, 
       'de R$ 2.001/mês a R$ 3000/mês': 2500,
      'de R$ 3.001/mês a R$ 4.000/mês': 3500,
      'de R$ 4.001/mês a R$ 6.000/mês': 5000, 
      'de R$ 6.001/mês a R$ 8.000/mês': 7000,
     'de R$ 8.001/mês a R$ 12.000/mês': 10000,
    'de R$ 12.001/mês a R$ 16.000/mês': 14000,
    'de R$ 16.001/mês a R$ 20.000/mês': 18000,
    'de R$ 20.001/mês a R$ 25.000/mês': 22500, 
    'de R$ 25.001/mês a R$ 30.000/mês': 27500, 
    'de R$ 30.001/mês a R$ 40.000/mês': 35000, 
              'Acima de R$ 40.001/mês': 40000}

dados['salario'] = dados["('P2_h ', 'Faixa salarial')"].map(salamap)  


dados['idade'] = dados["('P1_a_a ', 'Faixa idade')"]                                   #renomeando a variável idade
dados['gestor'] = dados["('P2_d ', 'Gestor?')"].map({0: 'não', 1: 'sim'})              # atribuindo "sim" e "não" na variável gestor
dados['se_considera_ds'] = dados["('P2_d ', 'Gestor?')"].map({0: 'não', 1: 'sim'})     # atribuindo "sim" e "não" na variável se considera ser gestor
dados['sexo'] = dados["('P1_b ', 'Genero')"                                           ]#renomeando a variável genero
dados['experiencia_ds'] = dados["('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')"]#renomeando a variável experiencia
dados['tipo_de_trabalho'] = dados["('P2_a ', 'Qual sua situação atual de trabalho?')"] #renomeando a variável trabalho
dados['escolaridade'] = dados["('P1_h ', 'Nivel de Ensino')"]                        #renomeando a variável escolaridade
dados['area_de_formacao'] = dados["('P1_i ', 'Área de Formação')"]        #renomeando a variável formação
dados['setor_de_mercado'] = dados["('P2_b ', 'Setor')"]          ##renomeando a variável setor de mercado

dados.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3  v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4  ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
# 1                      35-39           Masculino
# 2                      30-34           Masculino
# 3                      35-39            Feminino
# 4                      35-39           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
# 1                    Bahia (BA)                          BA
# 2           Santa Catarina (SC)                          SC
# 3                São Paulo (SP)                          SP
# ...

# %% [markdown]
# ##**Escolaridade**

# %%
# Percentual dos valores na escolaridade
dados['escolaridade'].value_counts(normalize=True).round(2)
# Out:
# Graduação/Bacharelado         0.34
# Pós-graduação                 0.31
# Estudante de Graduação        0.15
# Mestrado                      0.13
# Doutorado ou Phd              0.04
# Não tenho graduação formal    0.02
# Prefiro não informar          0.00
# Name: escolaridade, dtype: float64

# %% [markdown]
# A maior parte dos pesquisados possuem graduação e Pós graduação, ou ainda estão se graduando, enquanto que **a minoria possui mestrado ou doutorado**, isso quer dizer que esses profissionais são diferenciados na área de dados.

# %%
# buscando a média salário por escolaridade
dados.groupby('escolaridade').mean()[['salario']]
# Out:
#                                  salario
# escolaridade
# Doutorado ou Phd            12701.030928
# Estudante de Graduação       3963.210702
# Graduação/Bacharelado        8387.349398
# Mestrado                    13203.583062
# Não tenho graduação formal  10117.647059
# Prefiro não informar         6333.333333
# Pós-graduação               10503.856041

# %% [markdown]
# - Aqui verifica-se que média geral por escolaridade, quem têm **Pós graduação,mestrado ou doutorado varia acima dos 10 mil reais**, apenas **graduação entre 8 mil reais**, e **estudante de graduação na faixa dos 3 mil reais**.

# %%
# verificando a média salarial por profissão e escolaridade

dados.groupby(['profissao', 'escolaridade']).mean()[['salario']]
# Out:
#                                                      salario
# profissao           escolaridade
# Analista de BI      Doutorado ou Phd             8375.000000
#                     Estudante de Graduação       3358.974359
#                     Graduação/Bacharelado        6221.893491
#                     Mestrado                    10770.833333
#                     Não tenho graduação formal   7285.714286
#                     Prefiro não informar         8250.000000
#                     Pós-graduação                7473.214286
# Analista de Dados   Doutorado ou Phd             8666.666667
#                     Estudante de Graduação       3421.568627
#                     Graduação/Bacharelado        6677.419355
#                     Mestrado                     7984.375000
#                     Não tenho graduação formal  11250.000000
#                     Pós-graduação                7886.363636
# Cientista de Dados  Doutorado ou Phd            10000.000000
# ...

# %% [markdown]
# Aqui valida a importância de uma Pós graduação , mestrado ou doutorado em relação aos salários, quem mais estuda tende a ser melhor remunerado.

# %% [markdown]
# ##**Salários**

# %%
#plotando a distribuiçãp dos salários
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.hist(dados['salario'],bins=10, color= 'red', label='distribuição', alpha=0.5, edgecolor = 'black')
plt.xlabel('salários')
plt.ylabel('frequência')
plt.title('DISTRIBUIÇÃO DOS SALÁRIOS');

# %% [markdown]
# aqui percebe-se que a concentração dos salários então acima de **5 mil reais e abaixo de 15 mil reais**, e acima dos 15 mil reais dessa faixa existem poucos profissionais.

# %%
# Buscando a média geral dos salários
dados['salario'].mean()
# Out:
# 9361.099365750528

# %% [markdown]
# A **média** salarial em torno de **9.361 reais**, e a maioria dos pesquisados estão entre 5 e 15 mil reais.

# %%
print(dados.groupby('profissao').mean()[['salario']])

print(dados.groupby('profissao').mean()[['salario']].plot(kind = 'barh',
                                 edgecolor = 'black',
                                 title='Salário médio por profissão',
                                 color=['#6cc570','#706cc5'],
                                 figsize=(12,6),
                                 ));
# Out:
#                           salario
# profissao
# Analista de BI        6478.982301
# Analista de Dados     6779.320988
# Cientista de Dados    9113.874346
# Engenheiro de Dados  10230.650155
# Engenheiro de ML     10041.666667
# Outras                6673.780488
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Aqui percebe-se que, **engenheiro de ML, cientista de dados  e engenheiro de dados**, possuem as  médias salariais **acima de 9 mil reais**  enquanto que, os **analista de dados, analista de BI**,estão em torno **de 6 mil reais**.

# %%
# Buscando a qtdade deor gênero
print(dados['sexo'].value_counts(normalize=True))
dados['sexo'].value_counts(normalize=True).plot(kind = 'barh',
                                 edgecolor = 'black',
                                 title='Tipos de gênero',
                                 color=['#6cc570','#706cc5','r'],
                                 figsize=(10,6),
                                 );
# Out:
# Masculino    0.810586
# Feminino     0.186389
# Outro        0.003025
# Name: sexo, dtype: float64

# %% [markdown]
# Aqui verifica-se que **81%** dos profissionais são do **sexo masculino**

# %% [markdown]
# ---

# %%
# agrupando média salarial por sexo e profissão
dados.groupby(['profissao', 'sexo']).mean()[['salario']]
# Out:
#                                     salario
# profissao           sexo
# Analista de BI      Feminino    5938.144330
#                     Masculino   6626.760563
# Analista de Dados   Feminino    7210.843373
#                     Masculino   6630.705394
# Cientista de Dados  Feminino    7818.181818
#                     Masculino   9440.983607
# Engenheiro de Dados Feminino    7585.365854
#                     Masculino  10528.469751
#                     Outro      35000.000000
# Engenheiro de ML    Feminino    7666.666667
#                     Masculino  10589.743590
# Outras              Feminino    6774.193548
#                     Masculino   6688.931298
#                     Outro       4125.000000

# %% [markdown]
# Aqui verifica-se que em todas profissões **os homens ganham mais que as mulheres, com a execeção analistas de dados**.

# %%
# verificando a contagem, a média e o valor máximo dos salarios agrupados por sexo e profissão
dados.groupby(['profissao', 'sexo']).describe()['salario'][['count', 'mean', 'max']]
# Out:
#                                count          mean      max
# profissao           sexo
# Analista de BI      Feminino    97.0   5938.144330  22500.0
#                     Masculino  355.0   6626.760563  35000.0
# Analista de Dados   Feminino    83.0   7210.843373  35000.0
#                     Masculino  241.0   6630.705394  27500.0
# Cientista de Dados  Feminino    77.0   7818.181818  18000.0
#                     Masculino  305.0   9440.983607  40000.0
# Engenheiro de Dados Feminino    41.0   7585.365854  35000.0
#                     Masculino  281.0  10528.469751  40000.0
#                     Outro        1.0  35000.000000  35000.0
# Engenheiro de ML    Feminino     9.0   7666.666667  14000.0
#                     Masculino   39.0  10589.743590  40000.0
# Outras              Feminino    62.0   6774.193548  40000.0
#                     Masculino  262.0   6688.931298  40000.0
#                     Outro        4.0   4125.000000   5000.0

# %% [markdown]
# Aqui validamos que a mulheres ganha mais que os homens na condição de analista de dados

# %%
# validando visualmente as profissões com a média salarial
dados.groupby(['profissao', 'sexo']).mean()[['salario']].unstack().plot(kind = 'barh', figsize=(15,8), title='Médias salariais agrupadas por profissão e gêneros');

# %% [markdown]
# Aqui validamos visualmente que **as mulheres ganha mais que os homens na profissão de analista de dados**, enquanto que os homens têm médias salariais maiores em outras profissões.

# %% [markdown]
# ## **Idade**

# %%
# agrunpando média salariais por idade
dados.groupby('idade').mean()[['salario']]
# Out:
#             salario
# idade
# 17-21   2867.088608
# 22-24   4994.642857
# 25-29   8339.050132
# 30-34  10272.491349
# 35-39  11901.492537
# 40-44  12910.919540
# 45-49  13329.268293
# 50-54  11872.727273
# 55+    11500.000000

# %% [markdown]
# :Aqui verifica-se **à medida que a idade aumenta, o salário vai aumentando**.

# %%
# validando a média salarial por profissão
dados.groupby(['profissao', 'idade']).mean()[['salario']].unstack()
# Out:
#                          salario                                           \
# idade                      17-21        22-24         25-29         30-34
# profissao
# Analista de BI       2576.923077  3977.272727   5817.901235   6451.327434
# Analista de Dados    2750.000000  4194.444444   6411.504425   8075.949367
# Cientista de Dados   2133.333333  5546.875000   8868.589744  10580.459770
# Engenheiro de Dados  3884.615385  6712.962963   8852.941176  12987.341772
# Engenheiro de ML     3500.000000  3625.000000  11125.000000  11035.714286
# Outras               2500.000000  3086.956522   5564.935065   6905.063291
#
#                                                                              \
# idade                       35-39         40-44         45-49         50-54
# profissao
# Analista de BI        9000.000000   9769.230769   9681.818182  11750.000000
# Analista de Dados     7691.176471   9205.882353  12714.285714   8416.666667
# ...

# %% [markdown]
# Aqui validamos que em todas profissões **a média salarial cresce** com o aumento da **idade**, **isso comprova que a experiência é muito valiosa** para os profissionais

# %% [markdown]
# ## **Tamanho da Empresa**

# %%
# agruapando média salarial por porte da empresa
dados.groupby('tamanho_da_empresa').mean()[['salario']].round(2)
# Out:
#                     salario
# tamanho_da_empresa
# Grande              9987.85
# Média               9169.62
# Pequena             8147.18

# %% [markdown]
# Aqui verifica-se que **o tamanho da empresa por si só pouco interfere nas médias salariais**, porém , esse dado merece uma melhor investigação

# %%
# agrupando por profissão e porta da empresa as média salariais
dados.groupby(['profissao', 'tamanho_da_empresa']).mean()[['salario']]
# Out:
#                                              salario
# profissao           tamanho_da_empresa
# Analista de BI      Grande               7250.000000
#                     Média                5898.692810
#                     Pequena              5253.521127
# Analista de Dados   Grande               7536.458333
#                     Média                6032.258065
#                     Pequena              4833.333333
# Cientista de Dados  Grande              10088.942308
#                     Média                8300.884956
#                     Pequena              7295.081967
# Engenheiro de Dados Grande              10848.591549
#                     Média               10268.292683
#                     Pequena              8637.931034
# Engenheiro de ML    Grande              10847.826087
#                     Média                9437.500000
#                     Pequena              9055.555556
# Outras              Grande               8017.647059
# ...

# %%
# buscando visualizar os dados acima
dados.groupby(['profissao', 'tamanho_da_empresa']).mean()['salario'].unstack().plot(kind = 'barh',figsize=(15,8),title='Média salarial agrupada por profissão e tamanho da empresa');

# %% [markdown]
# Aqui validamos que ao agrupar por profissões e porte das empresas, percebe-se que **empresas pequenas tendem a ter menores salários**

# %% [markdown]
# ## **Experiência**

# %%
# verificando a média salarial por experiência
dados.groupby('experiencia_ds').mean()[['salario']].round(2)
# Out:
#                                          salario
# experiencia_ds
# Mais de 10 anos                         15818.01
# Menos de 1 ano                           4713.54
# Não tenho experiência na área de dados   6024.59
# de 1 a 2 anos                            6408.07
# de 2 a 3 anos                            8626.28
# de 4 a 5 anos                           11668.38
# de 6 a 10 anos                          14012.68

# %% [markdown]
# Aqui verifica-se que com **aumento do tempo de experiência tendem a aumentar a média salarial**, mas precisa de investigação melhor

# %%
# média salarial por tempo de experiência
dados.groupby(['profissao', 'experiencia_ds']).mean()[['salario']]
# Out:
#                                                                  salario
# profissao           experiencia_ds
# Analista de BI      Mais de 10 anos                         12819.444444
#                     Menos de 1 ano                           3623.595506
#                     Não tenho experiência na área de dados   7083.333333
#                     de 1 a 2 anos                            4384.259259
#                     de 2 a 3 anos                            6913.461538
#                     de 4 a 5 anos                            8176.470588
#                     de 6 a 10 anos                           8621.951220
# Analista de Dados   Mais de 10 anos                         10236.842105
#                     Menos de 1 ano                           3974.025974
#                     Não tenho experiência na área de dados   5500.000000
#                     de 1 a 2 anos                            5840.579710
# ...

# %% [markdown]
# Aqui percebe-se que profissinais **com mais de 10 anos de experiência**, se destacam com **maiores médias salariais**,
#
#
#
# e profissionais com **menos tempo de experiência ganham menos**

# %% [markdown]
# ## **Tipo de Trabalho**

# %%
# verificando a média salarial por tipo de trabalho
dados.groupby('tipo_de_trabalho').mean()[['salario']].round(2)
# Out:
#                                                      salario
# tipo_de_trabalho
# Desempregado e não estou buscando recolocação            NaN
# Desempregado, buscando recolocação                       NaN
# Empreendedor ou Empregado (CNPJ)                    11595.24
# Empregado (CLT)                                      8873.63
# Estagiário                                           1775.59
# Freelancer                                           5620.69
# Prefiro não informar                                 6357.14
# Servidor Público                                    11004.46
# Somente Estudante (graduação)                            NaN
# Somente Estudante (pós-graduação)                        NaN
# Trabalho na área Acadêmica/Pesquisador                   NaN
# Vivo fora do Brasil e trabalho para empresa de ...  24166.67
# Vivo no Brasil e trabalho remoto para empresa d...  23433.96

# %% [markdown]
# Aqui percebe-se que **as maiores médias salariais**, estão com profissionais que trabalham para **empresas fora do Brasil, seja presencialmente ou remotamente**, seguido de CNPJ,CLT e servidor público

# %%
# agrupando médias salariais por tipo de trabalho CPNJ, CLT ETC
dados.groupby(['profissao', 'tipo_de_trabalho']).mean()[['salario']].unstack()
# Out:
#                                              salario                  \
# tipo_de_trabalho    Empreendedor ou Empregado (CNPJ) Empregado (CLT)
# profissao
# Analista de BI                           8352.272727     6390.625000
# Analista de Dados                        6833.333333     6779.467681
# Cientista de Dados                       9732.142857     9128.378378
# Engenheiro de Dados                     11828.125000     8686.475410
# Engenheiro de ML                        13500.000000     9045.454545
# Outras                                   6461.538462     6394.144144
#
#                                                                      \
# tipo_de_trabalho      Estagiário    Freelancer Prefiro não informar
# profissao
# Analista de BI       1861.111111  10000.000000          2500.000000
# Analista de Dados    1660.000000   3000.000000                  NaN
# Cientista de Dados   1621.212121   2500.000000                  NaN
# ...

# %%
# aqui busco evidenciar as cores amarelas e verdes
cores=['#FBEAFF','#A178DF','#B39CD0','#DCB0FF','#FACCFF','#3E207C','#F9F871','#005B44']
dados.groupby(['profissao', 'tipo_de_trabalho']).mean()['salario'].unstack().plot(kind = 'barh', color = cores,figsize=(15,8), title='Média de salário por tipo de trabalho');

# %% [markdown]
# Aqui valida que as **maiores média salariais são de quem trabalha para empresas fora do Brasil**, seja presencialmente ou remotamente.

# %% [markdown]
# #**Profissional Cientista de Dados**

# %% [markdown]
# ---

# %% [markdown]
# ##Aqui foi interessante criar conjuntos de dados para uma melhor investigação

# %%
#criando conjuntos de dados convenientes através de alguns filtros

#profissoes de dados
lista = ['Cientista de Dados', 'Analista de Dados', 'Analista de BI', 'Engenheiro de Dados', 'Engenheiro de ML']

# criando conjunto de dados da lista de profissões
pds = dados[dados['profissao'].isin(lista)]

# atibuindo variávies

cds = dados[dados['profissao'] == 'Cientista de Dados'] 
ads = dados[dados['profissao'] == 'Analista de Dados'] 
abi = dados[dados['profissao'] == 'Analista de BI'] 
eds = dados[dados['profissao'] == 'Engenheiro de Dados'] 
eml = dados[dados['profissao'] == 'Engenheiro de ML']

# %%
# verificando conjunto de dados criado apenas com profissões da lista acima
pds=dados[dados['profissao'].isin(lista)]
pds
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 482   zyoz1s0ie1mva2zyoz1ybjvfggdfz89i                32.0
# 483   zxwv1axhtjl3ccjczxwv0wbf2qw8r8r5                28.0
# 485   zuvocreuesob1eg49awr9rxzuvocrq4z                35.0
# 486   ztrtwtz05am4swq65l1wztrtwk6u4guz                27.0
# 487   zt1nf4ujco617z39otzt1nfjtm4mj6l1                30.0
# ...                                ...                 ...
# 2635  05mb5ndhx8cj5q64qkegczl05mb5nd5c                27.0
# 2636  05h1fpcs8pjfh0105h15t6zmjl6go2zb                25.0
# 2639  03vzkm7kq2wnig2yjanxh03v5gze5mrs                34.0
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg                27.0
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18                24.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 482                       30-34           Masculino
# 483                       25-29            Feminino
# 485                       35-39            Feminino
# ...

# %% [markdown]
# ##**Salário**

# %%
# verificando a média slarial por profissão
pds.groupby('profissao').mean()['salario'].round(2)
# Out:
# profissao
# Analista de BI          6478.98
# Analista de Dados       6779.32
# Cientista de Dados      9113.87
# Engenheiro de Dados    10230.65
# Engenheiro de ML       10041.67
# Name: salario, dtype: float64

# %% [markdown]
# Aqui percebe-se que:
#
# **a média salarial dos engenheiros de dados** está na faixa de **10 mil**, enquanto que os
#
# **cientista de dados**, um pouco mais de **9 mil**, seguido por
#
#  **analista de dado e BI**, um pouco acima dos **6 mil**.

# %%
# agrupando por sexo e tamanho da empresa apenas cientista de dados
cds.groupby(['tamanho_da_empresa', 'sexo']).mean()['salario'].round(2).unstack().plot( kind = 'barh',figsize=(15,8),title='Cientista de dados agrupados por Tamanho da empresa por gênero');

# %% [markdown]
# Na profissão de **cientista de dados** gênero **masculino têm maiores médias salariais** tanto em empresas de **pequeno, médio ou grande porte**.

# %%
# agrupando média salariais por idade e profissão
pds.groupby(['profissao', 'idade']).mean()['salario'].round(2).unstack().T
# Out:
# profissao  Analista de BI  Analista de Dados  Cientista de Dados  \
# idade
# 17-21             2576.92            2750.00             2133.33
# 22-24             3977.27            4194.44             5546.88
# 25-29             5817.90            6411.50             8868.59
# 30-34             6451.33            8075.95            10580.46
# 35-39             9000.00            7691.18            11406.25
# 40-44             9769.23            9205.88            16647.06
# 45-49             9681.82           12714.29            13200.00
# 50-54            11750.00            8416.67            13900.00
# 55+              13800.00            8500.00             7000.00
#
# profissao  Engenheiro de Dados  Engenheiro de ML
# idade
# 17-21                  3884.62           3500.00
# 22-24                  6712.96           3625.00
# 25-29                  8852.94          11125.00
# 30-34                 12987.34          11035.71
# 35-39                 11000.00          17166.67
# ...

# %% [markdown]
# Aqui verifica-se, **à medida que as idades aumentam**, **os salários tendem a aumentar**,isso significa que a experiência é muito valiosa no ramo de dados.

# %%
# agrupando média slarial por tempo de experiencia
pds.groupby(['profissao', 'experiencia_ds']).mean()['salario'].round(2).unstack().T
# Out:
# profissao                               Analista de BI  Analista de Dados  \
# experiencia_ds
# Mais de 10 anos                               12819.44           10236.84
# Menos de 1 ano                                 3623.60            3974.03
# Não tenho experiência na área de dados         7083.33            5500.00
# de 1 a 2 anos                                  4384.26            5840.58
# de 2 a 3 anos                                  6913.46            7500.00
# de 4 a 5 anos                                  8176.47            8638.30
# de 6 a 10 anos                                 8621.95            8878.38
#
# profissao                               Cientista de Dados  \
# experiencia_ds
# Mais de 10 anos                                   15558.82
# Menos de 1 ano                                     4620.37
# Não tenho experiência na área de dados             1000.00
# de 1 a 2 anos                                      6306.82
# ...

# %% [markdown]
# Aqui evidenciou que;
#
#  **profissionais com mais de 10 anos de experiência são muito valorizados,** em contrapartida, os que têm
#
# **menos de 1 anos de experiência ganham menos**

# %% [markdown]
# #Linguagens de Programação

# %%
# verificando as linguagens de programação mais usadas por cientista de dados

cds.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# Out:
# <ipython-input-50-83db699ffe3a>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cds.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# ('P4_d_c ', 'Python')                           0.931937
# ('P4_d_a ', 'SQL')                              0.856021
# ('P4_d_b ', 'R ')                               0.353403
# ('P4_d_f ', 'Java')                             0.075916
# ('P4_d_h ', 'SAS/Stata')                        0.070681
# ('P4_d_m ', 'Javascript')                       0.054974
# ('P4_d_j ', 'Scala')                            0.039267
# ('P4_d_i ', 'Visual Basic/VBA')                 0.028796
# ('P4_d_d ', 'C/C++/C#')                         0.018325
# ('P4_d_g ', 'Julia')                            0.013089
# ('P4_d_n ', 'Não utilizo nenhuma linguagem')    0.010471
# ...

# %% [markdown]
# **93% dos cientistas de dados usam Python**,
#
#  **85% usam SQL**,
#
#  **apenas 35% usam R**

# %%
# linguagem usada pelo engenheiros de dados
eds.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# Out:
# <ipython-input-51-9cce20478c79>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   eds.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# ('P4_d_a ', 'SQL')                              0.944272
# ('P4_d_c ', 'Python')                           0.931889
# ('P4_d_f ', 'Java')                             0.185759
# ('P4_d_j ', 'Scala')                            0.157895
# ('P4_d_m ', 'Javascript')                       0.114551
# ('P4_d_b ', 'R ')                               0.049536
# ('P4_d_d ', 'C/C++/C#')                         0.030960
# ('P4_d_h ', 'SAS/Stata')                        0.027864
# ('P4_d_e ', '.NET')                             0.024768
# ('P4_d_i ', 'Visual Basic/VBA')                 0.024768
# ('P4_d_l ', 'PHP')                              0.018576
# ...

# %% [markdown]
# Os engenheiro de dados preferem **SQL com 94% e Python com 93%**

# %%
# verificando a linguagem dos analistas de dados
ads.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# Out:
# <ipython-input-52-4f17d663b824>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ads.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# ('P4_d_a ', 'SQL')                              0.873457
# ('P4_d_c ', 'Python')                           0.731481
# ('P4_d_b ', 'R ')                               0.188272
# ('P4_d_i ', 'Visual Basic/VBA')                 0.089506
# ('P4_d_h ', 'SAS/Stata')                        0.058642
# ('P4_d_f ', 'Java')                             0.052469
# ('P4_d_n ', 'Não utilizo nenhuma linguagem')    0.052469
# ('P4_d_m ', 'Javascript')                       0.049383
# ('P4_d_k ', 'Matlab')                           0.021605
# ('P4_d_j ', 'Scala')                            0.015432
# ('P4_d_l ', 'PHP')                              0.015432
# ...

# %% [markdown]
# **87%** dos analistas de dados preferem **SQL**,  e **73%** usam **PYTHON**.

# %%
# observando as principais linguagens dos analista de BI
abi.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# Out:
# <ipython-input-53-840976b84899>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   abi.filter(regex = 'P4_d').mean().sort_values(ascending = False)
# ('P4_d_a ', 'SQL')                              0.840708
# ('P4_d_c ', 'Python')                           0.595133
# ('P4_d_i ', 'Visual Basic/VBA')                 0.163717
# ('P4_d_b ', 'R ')                               0.121681
# ('P4_d_n ', 'Não utilizo nenhuma linguagem')    0.099558
# ('P4_d_f ', 'Java')                             0.073009
# ('P4_d_m ', 'Javascript')                       0.059735
# ('P4_d_h ', 'SAS/Stata')                        0.033186
# ('P4_d_j ', 'Scala')                            0.024336
# ('P4_d_d ', 'C/C++/C#')                         0.015487
# ('P4_d_e ', '.NET')                             0.013274
# ...

# %% [markdown]
# Aqui percebe-se que os **analistas de BI**, usam predominantemente o:
#
# **84% usam SQL**
#
# **59% usam Python**

# %%
# aqui observou-se a média agrupado por profissão das linguagens usadas, ordenada por cientista de dados
dados.groupby('profissao').mean().filter(regex = 'P4_d').T.sort_values(by = 'Cientista de Dados', ascending = False)
# Out:
# profissao                                     Analista de BI  \
# ('P4_d_c ', 'Python')                               0.595133
# ('P4_d_a ', 'SQL')                                  0.840708
# ('P4_d_b ', 'R ')                                   0.121681
# ('P4_d_f ', 'Java')                                 0.073009
# ('P4_d_h ', 'SAS/Stata')                            0.033186
# ('P4_d_m ', 'Javascript')                           0.059735
# ('P4_d_j ', 'Scala')                                0.024336
# ('P4_d_i ', 'Visual Basic/VBA')                     0.163717
# ('P4_d_d ', 'C/C++/C#')                             0.015487
# ('P4_d_g ', 'Julia')                                0.004425
# ('P4_d_n ', 'Não utilizo nenhuma linguagem')        0.099558
# ('P4_d_e ', '.NET')                                 0.013274
# ('P4_d_k ', 'Matlab')                               0.004425
# ('P4_d_l ', 'PHP')                                  0.013274
#
# ...

# %% [markdown]
# Aqui observou-se  que **Python e SQL são mais usadas por cientistas de dados, analistas de dados e engenheiros de dados**

# %% [markdown]
# #Ferramentas de Visualização

# %%
# Observando a ferramenta de visualização mais usdas por profissões
dados.groupby('profissao').mean().filter(regex = 'P4_h').T.sort_values(by = 'Cientista de Dados', ascending = False)
# Out:
# profissao                                           Analista de BI  \
# ('P4_h_a ', 'Microsoft PowerBI')                          0.730088
# ('P4_h_x ', 'Não utilizo nenhuma ferramenta de ...        0.015487
# ('P4_h_c ', 'Tableau')                                    0.196903
# ('P4_h_q ', 'Google Data Studio')                         0.236726
# ('P4_h_d ', 'Metabase')                                   0.079646
# ('P4_h_s ', 'Grafana')                                    0.019912
# ('P4_h_p ', 'Looker')                                     0.053097
# ('P4_h_v ', 'Fazemos todas as análises utilizan...        0.121681
# ('P4_h_b ', 'Qlik View/Qlik Sense')                       0.088496
# ('P4_h_f ', 'Redash')                                     0.011062
# ('P4_h_n ', 'Alteryx')                                    0.030973
# ('P4_h_u ', 'Pentaho')                                    0.099558
# ('P4_h_r ', 'SAS Visual Analytics')                       0.011062
# ...

# %% [markdown]
# Destaque para a ferramenta **Powerbi**
#
#  **73% analista de BI**,
#
# **55% analistas de dados**
#
#  **40% cientistas de dados**

# %% [markdown]
# #Técnicas dos Cientistas de Dados

# %%
# Observando as técnicas mais usadas por profissão
dados.groupby('profissao').mean().filter(regex = 'P8_b').T.sort_values(by = 'Cientista de Dados', ascending = False)
# Out:
# profissao                                           Analista de BI  \
# ('P8_b_a ', 'Utilizo modelos de regressão (line...        0.615385
# ('P8_b_b ', 'Utilizo redes neurais ou modelos b...        0.307692
# ('P8_b_f ', 'Utilizo métodos estatísticos cláss...        0.461538
# ('P8_b_h ', 'Desenvolvo técnicas de Clusterizaç...        0.384615
# ('P8_b_i ', 'Realizo previsões através de model...        0.384615
# ('P8_b_e ', 'Utilizo técnicas de NLP (Natural L...        0.230769
# ('P8_b_m ', 'Utilizo modelos de Detecção de Chu...        0.076923
# ('P8_b_d ', 'Utilizo métodos estatísticos Bayes...        0.153846
# ('P8_b_k ', 'Utilizo modelos de Machine Learnin...        0.000000
# ('P8_b_c ', 'Desenvolvo sistemas de recomendaçã...        0.076923
# ('P8_b_l ', 'Utilizo métodos de Visão Computaci...        0.230769
# ('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's...        0.000000
# ('P8_b_j ', 'Utilizo modelos de Reinforcement L...        0.000000
#
# ...

# %% [markdown]
# Aqui percebe-se as principais técnicas usadas por profissões:
#
# **modelos de regressão linear e logísticas** são usado praticamente por todas profissões em destaque.
#
# **modelos de classificação** é muito usado por cientista de dados e engenheiros de ML.
#
# **técnicas clássicas de estatística** são muitos requisitadas para cientistas de dado, analista de dados e engenheiro de dados.
#
# **Clusterização** é muito usado por cientista de dados , analista de dados e engenheiro de dados

# %% [markdown]
# ---

# %% [markdown]
# # **- STORYTELLING COM OS DADOS**

# %% [markdown]
# Três amigos, João, Maria e Antônio, resolveram abrir uma empresa no setor de dados, e para melhor se **estruturarem**, resolveram **analisar o perfil dos profissionais de dados no Brasil**, tendo como base  a pesquisa feita pelo  pessoal do Data Hackers com  **2.645 pessoas em 2021** que responderam sobre diversas variáveis de suas carreiras, desde salários,tempo de experiência até  conceitos e técnicas mais utilizados.
#
# Os amigos dedicaram suas análises em entender perfi de escolaridade, renda, linguagens usadas, técnicas mais utilizadas dentre outras informações que gerem padrões que irá auxiliar na tomada de decisão ao entrar no setor de dados.
#
# Com base em suas análises os dados revelaram que:
#
# - As profissões que contribuiram para esta pesquisa  **os analista de BI são a maioria com (24,3%),** seguido por **cientistas de dados com (20,5%)**, outras **profissões que são atividades ligadas à dados(17,6%)** e os **analistas de dados e engenheiros de dados (17%)**, isso nos deixa claro o quantitativo das profissões que mais contribuiram para pesquisa.
#
#
# -Os três amigos descobriram que **a média das idade é de 31 anos**, essas idades **variam entre 18 e 54 anos**,e que a metade dos entrevistados estão acima dos 30 anos, sendo que a  faixa etária predominante dos pesquisados **se concentram entre 25 e 34 anos**, sendo que a partir dos 50 anos têm poucos pesquisados.
#
# - A maior parte dos pesquisados possuem graduação e Pós graduação, ou ainda estão se graduando, enquanto que **a minoria possuem mestrado ou doutorado**, isso quer dizer que esses profissionais são diferenciados na área de dados.  observou-se que o grau de escolaridade interfere nas médias salariais, ou seja,**quanto maior o grau de escolaridade maior os salários**.
#
#  João queria saber  a  média geral por escolaridade, e verificou que, quem tem **Pós graduação,mestrado ou doutorado varia acima  de 10 mil reais**, apenas **graduação entre 8 mil reais**, e **estudante de graduação um pouco acima dos 3 mil reais**,mas ele deduziu que isso pode variar de acordo com o porte da empresa.
#
# - No geral a **média** salarial  estar em torno de **9.361 reais**,especificando por profissões destaca-se;
#
#    **Engenheiros de ML, cientistas de dados  e engenheiros de dados**, possuem a  média salariais **acima de 9 mil reais**  enquanto que , os **analistas de dados, analista de BI**,estão em torno **de 6 mil reais**.
#
# - Os amigos ficaram intrigados quanto aos gêneros participantes da pesquisa, e  verificou-se que **81%** dos profissionais são do **sexo masculino**, e em todas profissões, **os homens ganham mais que as mulheres, com a execeção dos analistas de dados**.
#
# - Os amigos queriam saber como se comportava os salários de acordo com o aumento da idade, e verifica-se que: **à medida que a idade aumenta, o salário vai aumentando**, validando a importância da experiência, Aqui percebe-se que profissinais **com mais de 10 anos de experiência**, se destacam com **maiores médias salariais acima de 14 mil ou mais**. perceberam também que, **empresas pequenas tendem a ter menores salários**.
#
# - Os meninos são bastante curiosos e resolveram investigar o tipo de trabalho que mais remunera  se são CLT ou PJ, e descobriram que: **as maiores médias salariais**, estão com profissionais que trabalham para **empresas fora do Brasil, seja presencialmente ou remotamente**, e os **CNPJ** que mais recebem **entre 11 mil reais**, enquanto que os **CLT acima de 8 mil**, e os que prestam serviços para empresas **fora do Brasil acima de 20 mil reais**.Ficou claro aqui que os PJ e os que trabalham para empresas fora do País estão com maiores remunerações.
#
#
# - À medida que as análises foram se aprofundando, os meninos resolveram focar em profissões específicas como Cientista de dados, analistas de dados e analistas de BI, para aprofundar em questões específicas como; linguagem de programação e alguns conceitos usado dentro do ambiente de trabalho, e assim chegaram a seguintes observações:
#
#  -- Os cientistas de dados usam **Python com 93%**, **85% usam SQL**, Apenas **35% usam R**.
#
#  -- Os engenheiro de dados preferem **SQL com 94%** e **Python com 93%**
#
#  -- Os analistas de dados preferem **SQL com 87%**, e **73% usam PYTHON**
#
#  -- Os analistas de BI, usam predominantemente com **84% usam SQL** e **59% usam Python**
#
#
#  -  Observou-se  que **Python e SQL são mais usadas** por cientistas de dados, analistas de dados e engenheiros de dados.Aqui os meninos já viram que vão  investir em Python e SQL.
#
#  Os meninos aprofundaram suas análises queriam saber qual a ferramenta de visualização mais se usa no ambiente de trabalho, e descobriram que o **POWERBI foi a ferramenta mais usada pelos profissionais** , tendo como;
#
# -**73% analistas de BI**,
#
# -**55% analistas de dados**
#
# -**40% cientistas de dados**
#
# -Os três amigos também queriam saber sobre algumas técnicas que seriam usadas principalmente em ambientes de trabalho por profissões, sendo assim , chegararm a seguintes observações;
#
# -**Modelos de regressão linear e logísticas** são usado praticamente por todas profissões em destaque.
#
# -**Modelos de classificação** é muito usado por cientista de dados e engenheiros de ML.
#
# -**Técnicas clássicas de estatística** são muitos requisitadas para cientistas de dado, analistas de dados e engenheiro de dados.
#
# -**Clusterização** é muito usado por cientista de dados , analistas de dados e engenheiros de dados.
#
# -Para aprofundamento resolveram observar as técnicas mais usadas pelos **cientista de dados** e chegaram a seguinte observações;
#
# -79% usam modelo de regressão linear e logística
#
# -71% Utiliza redes neurais ou modelos baseados em árvore para criar modelos de classificação
#
# -60% Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados
#
# -59% Desenvolve técnicas de Clusterização (K-means, Spectral, DBScan)
#
# -48% 'Realizo previsões através de modelos de Séries Temporais (Time Series)')
#
# -37%  'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados
#
# -29% Utilizo modelos de Detecção de Churn')
#
# -11% 'Utilizo métodos de Visão Computacional')
#
#
#
# Com esses dados evidenciados, os três amigos têm informações valiosas para a tomada de decisão ao entrar com abertura de uma empresa do setor de dados , e assim, se organizar e estruturar de forma acertada haja visto que as  informações que traçam o perfil desses profissionais validam uma decisão estratégica com base na cultura dos dados.
